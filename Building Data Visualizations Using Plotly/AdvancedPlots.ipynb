# %%
import plotly
import chart_studio.plotly as py
import plotly.offline as offline

offline.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import plotly.figure_factory as ff

# %%
tasks = [
    dict(
        Task = 'Task 1',
        Start = '2018-01-01',
        Finish = '2018-02-28'
    ),
    dict(
        Task = 'Task 2',
        Start = '2018-03-05',
        Finish = '2018-05-15'
    ),
    dict(
        Task = 'Task 3',
        Start = '2018-05-01',
        Finish = '2018-06-30'
    )
]

# %%
fig = ff.create_gantt(tasks)
offline.iplot(fig)
# Out:
# <div>
#
#
#             <div id="ef753f74-61dc-4109-8f63-f5550ca9262c" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ef753f74-61dc-4109-8f63-f5550ca9262c")) {
#                     Plotly.newPlot(
#                         'ef753f74-61dc-4109-8f63-f5550ca9262c',
# ...

# %%
tasks = [
    dict(
        Task = 'Task 1',
        Start = '2018-01-01',
        Finish = '2018-02-28',
        Complete = 100
    ),
    dict(
        Task = 'Task 2',
        Start = '2018-03-05',
        Finish = '2018-05-15',
        Complete = 60
    ),
    dict(
        Task = 'Task 3',
        Start = '2018-05-01',
        Finish = '2018-06-30',
        Complete = 20
    )
]
fig = ff.create_gantt(
    tasks,
    title = 'Gantt Chart with a Color Scale',
    colors = 'Picnic',
    index_col = 'Complete',
    show_colorbar = True
)
offline.iplot(fig)
# Out:
# <div>
#
#
#             <div id="d32d57bc-ca0c-43e3-8507-4367bdff8935" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d32d57bc-ca0c-43e3-8507-4367bdff8935")) {
#                     Plotly.newPlot(
#                         'd32d57bc-ca0c-43e3-8507-4367bdff8935',
# ...

# %%
import pandas as pd

# %%
schedule = pd.DataFrame(dict(
    Task = ['Sleep','Breaskfast','Music','Math','Lunch','Physics','Music','Nap','Tennis','Dinner','Music','History'],
    Start = ['2018-07-01 0:00:00','2018-07-01 7:30:00','2018-07-01 8:00:00','2018-07-01 9:00:00','2018-07-01 12:00:00',
            '2018-07-01 13:00:00','2018-07-01 14:00:00','2018-07-01 16:00:00','2018-07-01 17:30:00','2018-07-01 20:00:00',
            '2018-07-01 20:30:00','2018-07-01 21:00:00'],
    Finish = ['2018-07-01 7:00:00','2018-07-01 8:00:00','2018-07-01 12:00:00','2018-07-01 12:00:00','2018-07-01 13:00:00',
            '2018-07-01 14:30:00','2018-07-01 15:30:00','2018-07-01 16:30:00','2018-07-01 19:00:00','2018-07-01 20:30:00',
            '2018-07-01 22:00:00','2018-07-01 22:00:00'],
    Category = ['Rest','Eat','Music','Homework','Eat','Homework','Music','Rest','Play','Eat','Music','Homework']
))
schedule
# Out:
#           Task                Start               Finish  Category
# 0        Sleep   2018-07-01 0:00:00   2018-07-01 7:00:00      Rest
# 1   Breaskfast   2018-07-01 7:30:00   2018-07-01 8:00:00       Eat
# 2        Music   2018-07-01 8:00:00  2018-07-01 12:00:00     Music
# 3         Math   2018-07-01 9:00:00  2018-07-01 12:00:00  Homework
# 4        Lunch  2018-07-01 12:00:00  2018-07-01 13:00:00       Eat
# 5      Physics  2018-07-01 13:00:00  2018-07-01 14:30:00  Homework
# 6        Music  2018-07-01 14:00:00  2018-07-01 15:30:00     Music
# 7          Nap  2018-07-01 16:00:00  2018-07-01 16:30:00      Rest
# 8       Tennis  2018-07-01 17:30:00  2018-07-01 19:00:00      Play
# 9       Dinner  2018-07-01 20:00:00  2018-07-01 20:30:00       Eat
# 10       Music  2018-07-01 20:30:00  2018-07-01 22:00:00     Music
# 11     History  2018-07-01 21:00:00  2018-07-01 22:00:00  Homework

# %%
color_dict = dict(
    Rest = 'rgb(46,137,205)',
    Eat = 'rgb(114,44,121)',
    Homework = 'rgb(198,47,105)',
    Play = '#BD8FD7',
    Music = '#78F7DE'
)

# %%
fig = ff.create_gantt(
    schedule,
    title = 'Schedule for 1-July-2018',
    colors = color_dict,
    index_col = 'Category',
    show_colorbar = True,
    bar_width = 0.5,
    showgrid_x = True,
    showgrid_y = True
)
offline.iplot(fig)
# Out:
# <div>
#
#
#             <div id="bdf3f142-2aa8-483e-9e99-e5141c3cb2ef" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("bdf3f142-2aa8-483e-9e99-e5141c3cb2ef")) {
#                     Plotly.newPlot(
#                         'bdf3f142-2aa8-483e-9e99-e5141c3cb2ef',
# ...

# %%
color_list = [
    '#BD8FD7',
    '#78F7DE',
    'rgb(46,137,205)',
    'rgb(114,44,121)',
    'rgb(198,47,105)'
]

# %%
fig = ff.create_gantt(
    schedule,
    title = 'Schedule for 1-July-2018',
    colors = color_list,
    index_col = 'Category',
    show_colorbar = True,
    bar_width = 0.5,
    showgrid_x = True,
    showgrid_y = True
)
offline.iplot(fig)
# Out:
# <div>
#
#
#             <div id="184c8af8-f33a-4ee6-8e21-7cfe19e065a3" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("184c8af8-f33a-4ee6-8e21-7cfe19e065a3")) {
#                     Plotly.newPlot(
#                         '184c8af8-f33a-4ee6-8e21-7cfe19e065a3',
# ...

# %%
fig = ff.create_gantt(
    schedule,
    title = 'Schedule for 1-July-2018',
    colors = color_list,
    index_col = 'Category',
    show_colorbar = True,
    showgrid_x = True,
    showgrid_y = True,
    group_tasks = True
)
offline.iplot(fig)
# Out:
# <div>
#
#
#             <div id="23525b26-45d0-4c25-9adc-bcd9a234302c" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("23525b26-45d0-4c25-9adc-bcd9a234302c")) {
#                     Plotly.newPlot(
#                         '23525b26-45d0-4c25-9adc-bcd9a234302c',
# ...

# %%
import plotly.graph_objs as go

# %%
locations = [
    'Uptown',
    'Midtown',
    'Downtown',
    'Front Lobby',
    'Rear Lobby',
    'Conference Room'
]

# %%
data = go.Sankey(
    node = dict(
        label = locations
    ),
    link = dict(
        source = [0,0,1,1,2,3,4],
        target = [3,4,3,4,3,5,5],
        value = [2,2,4,1,5,9,3]
    )
)

# %%
layout = go.Layout(
    title = 'Basic Sankey Diagram',
    font = dict(
        size = 12
    )
)

# %%
fig = go.Figure(
    data = [data],
    layout = layout
)
offline.iplot(fig)
# Out:
# <div>
#
#
#             <div id="087b5122-f546-4901-9ed5-a2bcb32e64d3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("087b5122-f546-4901-9ed5-a2bcb32e64d3")) {
#                     Plotly.newPlot(
#                         '087b5122-f546-4901-9ed5-a2bcb32e64d3',
#                         [{"link": {"source": [0, 0, 1, 1, 2, 3, 4], "target": [3, 4, 3, 4, 3, 5, 5], "value": [2, 2, 4, 1, 5, 9, 3]}, "node": {"label": ["Uptown", "Midtown", "Downtown", "Front Lobby", "Rear Lobby", "Conference Room"]}, "type": "sankey"}],
# ...

# %%
data = pd.read_csv('https://raw.githubusercontent.com/plotly/dash-app-datasets/master/refugee-movement.csv')
data
# Out:
#     Source  Target  Value    Color                      Node, Label
# 0        0      14    548  #262C46                 People from Iran
# 1        0      15    167  #262C46          People from Afghanistan
# 2        1      14    135  #262C46             People from Pakistan
# 3        1      15     37  #262C46                 People from Iraq
# 4        2      14    105  #262C46           People from Bangladesh
# 5        2      15     74  #262C46              People from Myanmar
# 6        3      14    106  #262C46              People from Somalia
# 7        3      15     21  #262C46              People from Lebanon
# 8        4      14     74  #262C46  People from Myanmar (Stateless)
# 9        4      15     42  #262C46            People from Sri Lanka
# 10       5      14     53  #262C46                 Stateless People
# 11       5      15     17  #262C46                People from Nepal
# 12       6      14     48  #262C46                     Other People
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Source       37 non-null     int64
#  1   Target       37 non-null     int64
#  2   Value        37 non-null     int64
#  3   Color        37 non-null     object
#  4   Node, Label  26 non-null     object
# dtypes: int64(3), object(2)
# memory usage: 1.6+ KB

# %%
data_trace = go.Sankey(
    node = dict(
        pad = 10,
        thickness = 30,
        label = data['Node, Label'].dropna(),
        color = data['Color']
    ),
    link = dict(
        source = data['Source'],
        target = data['Target'],
        value = data['Value']
    )
)
layout = go.Layout(
    title = 'Refugee Movement Through Manus and Nauru'
)
fig = go.Figure(
    data = [data_trace],
    layout = layout
)
offline.iplot(fig)
# Out:
# <div>
#
#
#             <div id="dbcc3b7a-dffd-4a09-b004-1d42a7fd98de" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("dbcc3b7a-dffd-4a09-b004-1d42a7fd98de")) {
#                     Plotly.newPlot(
#                         'dbcc3b7a-dffd-4a09-b004-1d42a7fd98de',
# ...

# %%
import numpy as np

# %%
n = 50

random_x = np.random.randn(n)

random_y = np.random.randn(n)

random_z = np.random.randn(n)

random_a = np.random.randn(n)

random_b = np.random.randn(n)

# %%
trace = go.Scatter3d(
    x = random_x,
    y = random_y,
    z = random_z,
    mode = 'markers',
    marker = dict(
        color = random_a,
        colorscale = 'Rainbow',
        sizemode = 'area',
        size = 1000*(random_b-min(random_b))
    )
)

# %%
offline.iplot([trace])
# Out:
# <div>
#
#
#             <div id="fba53664-5df7-4b6a-a86f-150339aa7541" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("fba53664-5df7-4b6a-a86f-150339aa7541")) {
#                     Plotly.newPlot(
#                         'fba53664-5df7-4b6a-a86f-150339aa7541',
# ...

# %%
planets = pd.DataFrame(dict(
    planet = ['Mercury','Venus','Earth','Mars','Jupiter','Saturn','Uranus','Neptune'],
    no_of_moons = [0,0,1,2,67,62,27,14],
    distance_from_sun = [57.9,108.2,149.6,227.9,778.6,1434,2871,4495],
    period_of_revolution_around_sun = [87.96,224.68,365.26,686.98,4332.70,10765.12,30698.51,60216.72],
    planet_diameter = [4879.4,12104,12742,6779,139820,116460,50724,49244]
))

# %%
colors = [
    '#D5D2D1',
    '#F8B581',
    '#182A61',
    '#B53B03',
    '#B9CBD5',
    '#E0CDAD',
    '#13F9FA',
    '#3454DF',
    '#E9E8D2'
]

# %%
trace = go.Scatter3d(
    x = planets['distance_from_sun'],
    y = planets['period_of_revolution_around_sun'],
    z = planets['no_of_moons'],
    text = planets['planet'],
    mode = 'markers',
    marker = dict(
        sizemode = 'diameter',
        sizeref = 750,
        size = planets['planet_diameter'],
        color = colors
    )
)
data = [trace]

# %%
layout = go.Layout(
    width = 800,
    height = 800,
    title = 'Planets of our Solar System',
    scene = dict(
        xaxis = dict(
            title = 'Distance from Sun',
            color = 'white',
            titlefont = dict(
                color = 'yellow'
            )
        ),
        yaxis = dict(
            title = 'Period of Revolutions Around Sun (Earth Days)',
            color = 'white',
            titlefont = dict(
                color = 'yellow'
            )
        ),
        zaxis = dict(
            title = 'Moon Count',
            color = 'white',
            titlefont = dict(
                color = 'yellow'
            )
        ),
        bgcolor = '#141836'
    )
)

# %%
fig = go.Figure(
    data = data,
    layout = layout
)
offline.iplot(fig)
# Out:
# <div>
#
#
#             <div id="f2e5f070-a556-4174-a02c-2292e5fef23a" class="plotly-graph-div" style="height:800px; width:800px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f2e5f070-a556-4174-a02c-2292e5fef23a")) {
#                     Plotly.newPlot(
#                         'f2e5f070-a556-4174-a02c-2292e5fef23a',
# ...

# %%
z = [
    [16,18,17,16],
    [15,17,17,16],
    [12,14,12,14]
]

# %%
data = [go.Surface(z = z)]

# %%
offline.iplot(data)
# Out:
# <div>
#
#
#             <div id="c2d47903-bb2d-4294-8221-37854c0cefa6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c2d47903-bb2d-4294-8221-37854c0cefa6")) {
#                     Plotly.newPlot(
#                         'c2d47903-bb2d-4294-8221-37854c0cefa6',
#                         [{"type": "surface", "z": [[16, 18, 17, 16], [15, 17, 17, 16], [12, 14, 12, 14]]}],
# ...

# %%
volcano = pd.read_csv('https://python-graph-gallery.com/wp-content/uploads/volcano.csv')
volcano
# Out:
#      V1   V2   V3   V4   V5   V6   V7   V8   V9  V10  ...  V52  V53  V54  V55  \
# 0   100  100  101  101  101  101  101  100  100  100  ...  107  107  107  106
# 1   101  101  102  102  102  102  102  101  101  101  ...  108  108  107  107
# 2   102  102  103  103  103  103  103  102  102  102  ...  109  108  108  107
# 3   103  103  104  104  104  104  104  103  103  103  ...  109  109  108  108
# 4   104  104  105  105  105  105  105  104  104  103  ...  110  109  109  108
# ..  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 82   99   99   99   99  100  100  101  101  102  102  ...   95   95   95   95
# 83   98   99   99   99   99  100  100  101  101  102  ...   95   95   94   94
# 84   98   98   98   99   99   99  100  100  101  101  ...   94   94   94   94
# 85   97   98   98   98   99   99   99  100  100  100  ...   94   94   94   94
# 86   97   97   97   98   98   99   99   99  100  100  ...   94   94   94   94
#
#     V56  V57  V58  V59  V60  V61
# ...

# %%
volcano.values
# Out:
# array([[100, 100, 101, ..., 104, 104, 103],
#        [101, 101, 102, ..., 105, 104, 104],
#        [102, 102, 103, ..., 105, 105, 104],
#        ...,
#        [ 98,  98,  98, ...,  94,  94,  94],
#        [ 97,  98,  98, ...,  94,  94,  94],
#        [ 97,  97,  97, ...,  94,  94,  94]], dtype=int64)

# %%
data = go.Surface(
    z = volcano.values,
    colorscale = 'Jet'
)

# %%
layout = go.Layout(
    width = 800,
    height = 800,
    title = 'Volcano Elevation',
    autosize = False
)

# %%
offline.iplot(
    go.Figure(
        data = [data],
        layout = layout
    )
)
# Out:
# <div>
#
#
#             <div id="a315c09d-43a2-451a-9801-b6652bcc546a" class="plotly-graph-div" style="height:800px; width:800px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a315c09d-43a2-451a-9801-b6652bcc546a")) {
#                     Plotly.newPlot(
#                         'a315c09d-43a2-451a-9801-b6652bcc546a',
# ...

# %%
x0 = [0]
y0 = [11]

# %%
x1 = [0,1]
y1 = [11,13]

# %%
x2 = [0,1,2]
y2 = [11,13,12]

# %%
layout = go.Layout(
    xaxis = dict(
        range = [0,3]
    ),
    yaxis = dict(
        range = [10,15]
    ),
    updatemenus = [
        dict(
            type = 'buttons',
            buttons = [
                dict(
                    label = 'Play',
                    method = 'animate',
                    args = [None]
                )
            ]
        )
    ]
)

# %%
frames = go.Frames(
    [
        dict(
            data = [
                dict(
                    x = x0,
                    y = y0
                )
            ]
        ),
        dict(
            data = [
                dict(
                    x = x1,
                    y = y1
                )
            ]
        ),
        dict(
            data = [
                dict(
                    x = x2,
                    y = y2
                )
            ]
        )
    ]
)

# %%
fig = go.Figure(
    data = [{}],
    layout = layout,
    frames = frames
)
offline.iplot(fig)
# Out:
# <div>
#
#
#             <div id="06e19b66-6fd7-41d6-809a-1e0f03992135" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("06e19b66-6fd7-41d6-809a-1e0f03992135")) {
#                     Plotly.newPlot(
#                         '06e19b66-6fd7-41d6-809a-1e0f03992135',
#                         [{"type": "scatter"}],
# ...

# %%
x3 = [2,3]
y3 = [13,14]

# %%
frames = go.Frames(
    [
        dict(data = [dict(x = x0,y = y0)]),
        dict(data = [dict(x = x1,y = y1)]),
        dict(data = [dict(x = x2,y = y2)]),
        dict(data = [dict(x = x3,y = y3)])
    ]
)

# %%
fig = go.Figure(
    data = [{}],
    layout = layout,
    frames = frames
)
offline.iplot(fig)
# Out:
# <div>
#
#
#             <div id="e9487149-e308-40c1-9eaa-ee28ad34d6ce" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e9487149-e308-40c1-9eaa-ee28ad34d6ce")) {
#                     Plotly.newPlot(
#                         'e9487149-e308-40c1-9eaa-ee28ad34d6ce',
#                         [{"type": "scatter"}],
# ...

# %%
data = pd.read_csv('https://raw.githubusercontent.com/chainhaus/pythoncourse/master/avocado.csv')
data_ca = data.loc[(data['region'] == 'California') & (data['type'] == 'organic')]
data_ca = data_ca.sort_values(by = ['Date'])
data_ca.head()
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume       4046      4225  \
# 9489          51  2015-01-04          1.24     142349.77  107490.73  25711.96
# 9488          50  2015-01-11          1.10     158110.68  123712.51  25975.27
# 9487          49  2015-01-18          1.24     195207.60  123138.29  58616.16
# 9486          48  2015-01-25          1.30     121698.02   80952.24  28216.13
# 9485          47  2015-02-01          1.11     196031.90  142332.45  41999.51
#
#       4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 9489  2.93     9144.15     9144.15         0.0          0.0  organic  2015
# 9488  1.47     8421.43     8421.43         0.0          0.0  organic  2015
# 9487  0.00    13453.15    13453.15         0.0          0.0  organic  2015
# 9486  0.00    12529.65    12529.65         0.0          0.0  organic  2015
# 9485  2.92    11697.02    11697.02         0.0          0.0  organic  2015
#
#           region
# 9489  California
# ...

# %%
avgPrices = list(data_ca['AveragePrice'])
dateList = list(data_ca['Date'])

# %%
xList = []
yList = []
framesList = []

# %%
for i in range(len(dateList)):
    xList.append(dateList[i])
    yList.append(avgPrices[i])
    framesList.append(dict(data = [dict(x = xList.copy(), y = yList.copy())]))

# %%
playButton = dict(
    label = 'Play',
    method = 'animate',
    args = [None,
            dict(
                fromcurrent = True,
                transition = dict(duration = 200),
                frame = dict(duration = 100)
            )
           ]
)
pauseButton = dict(
    label = 'Pause',
    method = 'animate',
    args = [[None], dict(mode = 'immediate')]
)

# %%
layout = go.Layout(
    xaxis = dict(range = [dateList[0],dateList[-1]]),
    yaxis = dict(range = [0, 1 + max(avgPrices)]),
    updatemenus = [
        dict(
            type = 'buttons',
            buttons = [playButton,pauseButton]
        )
    ]
)
layout
# Out:
# Layout({
#     'updatemenus': [{'buttons': [{'args': [None, {'fromcurrent': True,
#                                            'transition': {'duration': 200},
#                                            'frame': {'duration': 100}}],
#                                   'label': 'Play',
#                                   'method': 'animate'},
#                                  {'args': [[None], {'mode': 'immediate'}], 'label': 'Pause', 'method': 'animate'}],
#                      'type': 'buttons'}],
#     'xaxis': {'range': ['2015-01-04', '2018-03-25']},
#     'yaxis': {'range': [0, 3.58]}
# })

# %%
fig = go.Figure(
    data = [{}],
    layout = layout,
    frames = framesList
)
offline.iplot(fig)
# Out:
# <div>
#
#
#             <div id="f0f7fe17-3265-4072-a3cd-5b4fa9e4c9c3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f0f7fe17-3265-4072-a3cd-5b4fa9e4c9c3")) {
#                     Plotly.newPlot(
#                         'f0f7fe17-3265-4072-a3cd-5b4fa9e4c9c3',
#                         [{"type": "scatter"}],
# ...
